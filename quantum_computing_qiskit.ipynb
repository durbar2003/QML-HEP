# %%
# !pip install qiskit
# Out:
# Collecting qiskit
#   Downloading qiskit-0.42.0.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting qiskit-terra==0.23.2
#   Downloading qiskit_terra-0.23.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 2.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting qiskit-aer==0.12.0
#   Downloading qiskit_aer-0.12.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting qiskit-ibmq-provider==0.20.2
#   Downloading qiskit_ibmq_provider-0.20.2-py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 kB 2.7 MB/s eta 0:00:002.9 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.0 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-aer==0.12.0->qiskit) (1.10.0)
# Requirement already satisfied: numpy>=1.16.3 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-aer==0.12.0->qiskit) (1.21.5)
# Collecting websocket-client>=1.5.1
#   Using cached websocket_client-1.5.1-py3-none-any.whl (55 kB)
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 2.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.19 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.28.1)
# Collecting requests-ntlm<=1.1.0
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-ibmq-provider==0.20.2->qiskit) (1.26.11)
# Collecting rustworkx>=0.12.0
#   Downloading rustworkx-0.12.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: psutil>=5 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-terra==0.23.2->qiskit) (5.9.0)
# Collecting symengine>=0.9
#   Downloading symengine-0.9.2-cp39-cp39-manylinux2010_x86_64.whl (37.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 811.0 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: dill>=0.3 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-terra==0.23.2->qiskit) (0.3.4)
# Collecting stevedore>=3.0.0
#   Using cached stevedore-5.0.0-py3-none-any.whl (49 kB)
# Requirement already satisfied: sympy>=1.3 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-terra==0.23.2->qiskit) (1.10.1)
# Requirement already satisfied: ply>=3.10 in /home/durbar/anaconda3/lib/python3.9/site-packages (from qiskit-terra==0.23.2->qiskit) (3.11)
# Requirement already satisfied: six>=1.5 in /home/durbar/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/durbar/anaconda3/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/durbar/anaconda3/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/durbar/anaconda3/lib/python3.9/site-packages (from requests>=2.19->qiskit-ibmq-provider==0.20.2->qiskit) (2.10)
# Requirement already satisfied: cryptography>=1.3 in /home/durbar/anaconda3/lib/python3.9/site-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (37.0.1)
# Collecting ntlm-auth>=1.0.2
#   Downloading ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.11.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/durbar/anaconda3/lib/python3.9/site-packages (from sympy>=1.3->qiskit-terra==0.23.2->qiskit) (1.2.1)
# Requirement already satisfied: cffi>=1.12 in /home/durbar/anaconda3/lib/python3.9/site-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (1.15.1)
# Requirement already satisfied: pycparser in /home/durbar/anaconda3/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider==0.20.2->qiskit) (2.21)
# Building wheels for collected packages: qiskit
#   Building wheel for qiskit (setup.py) ... done
#   Created wheel for qiskit: filename=qiskit-0.42.0-py3-none-any.whl size=12920 sha256=898df6f19b4d99e213f1be88f654bf4c3581d649c0f49acb262e3fef67e93d05
#   Stored in directory: /home/durbar/.cache/pip/wheels/e4/4f/33/a48152b8216ba8d0c81b13a09f9f0fb672268100d4de8099fe
# Successfully built qiskit
# Installing collected packages: websockets, websocket-client, symengine, rustworkx, pbr, ntlm-auth, stevedore, requests-ntlm, qiskit-terra, qiskit-ibmq-provider, qiskit-aer, qiskit
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Uninstalling websocket-client-0.58.0:
#       Successfully uninstalled websocket-client-0.58.0
# Successfully installed ntlm-auth-1.5.0 pbr-5.11.1 qiskit-0.42.0 qiskit-aer-0.12.0 qiskit-ibmq-provider-0.20.2 qiskit-terra-0.23.2 requests-ntlm-1.1.0 rustworkx-0.12.1 stevedore-5.0.0 symengine-0.9.2 websocket-client-1.5.1 websockets-10.4

# %%
from qiskit import QuantumCircuit, Aer, execute

# Create a quantum circuit with 4 qubits and 1 classical bit
circuit = QuantumCircuit(4, 1)

# Apply Hadamard gate to the first qubit
circuit.h(0)

# Rotate the second qubit by pi/3 around X
circuit.rx(2 * np.pi / 3, 1)

# Apply Hadamard gate to the third and fourth qubit
circuit.h(2)
circuit.h(3)

# Perform a swap test
circuit.h(0)
circuit.cx(0, 3)
circuit.cx(1, 2)
circuit.h(0)
circuit.measure(0, 0)

# Draw the circuit
print(circuit.draw())

# Simulate the circuit
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, simulator).result()
counts = result.get_counts(circuit)
print(counts)
